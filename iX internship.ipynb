# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("/Users/ahmadasdo/Library/Containers/com.microsoft.Excel/Data/Downloads/Maintenance Central File V7 20210121.xlsm")

# %%
df
# Out:
#       No.  Project                 Date    Date Issue Closed Rate Urgency  \
# 0       0        +                  NaN                  NaN          NaN
# 1       0  Aerosud  2019-09-16 00:00:00  2019-09-16 00:00:00          Low
# 2       0  Aerosud  2019-09-11 00:00:00  2019-09-11 00:00:00          Low
# 3       0  Aerosud  2019-10-18 00:00:00  2019-10-24 00:00:00         High
# 4       0  Aerosud  2019-10-06 00:00:00  2019-10-06 00:00:00          Low
# ...   ...      ...                  ...                  ...          ...
# 1267    7      NaN                  NaN                  NaN          NaN
# 1268    7      NaN                  NaN                  NaN          NaN
# 1269    7      NaN                  NaN                  NaN          NaN
# 1270    7      NaN                  NaN                  NaN          NaN
# 1271    7      NaN                  NaN                  NaN          NaN
#
#        Component Installation / Component Task Carried Out By  \
# 0            NaN                      NaN                 NaN
# 1      PV System             Installation            Natheera
# 2      PV System             Installation            Natheera
# 3     Monitoring             Installation               David
# 4      PV System             Installation            Natheera
# ...          ...                      ...                 ...
# 1267         NaN                      NaN                 NaN
# 1268         NaN                      NaN                 NaN
# 1269         NaN                      NaN                 NaN
# 1270         NaN                      NaN                 NaN
# 1271         NaN                      NaN                 NaN
#
#                                                Details   Status  ...  \
# 0                                                   NaN     NaN  ...
# 1                               System online. System 1  Closed  ...
# 2                               System online. System 2  Closed  ...
# 3     System 2 offline due to communication fault. C...  Closed  ...
# 4                                    PV modules cleaned  Closed  ...
# ...                                                 ...     ...  ...
# 1267                                                NaN     NaN  ...
# 1268                                                NaN     NaN  ...
# 1269                                                NaN     NaN  ...
# 1270                                                NaN     NaN  ...
# 1271                                                NaN     NaN  ...
#
#           Lists  % Loss Due To Error  \
# 0        Status                  NaN
# 1         Open                   NaN
# 2        Closed                  NaN
# 3           NaN                  NaN
# 4     Component                  NaN
# ...         ...                  ...
# 1267        NaN                  NaN
# 1268        NaN                  NaN
# 1269        NaN                  NaN
# 1270        NaN                  NaN
# 1271        NaN                  NaN
#
#                                         Action / Result  \
# 0     Analysis performed / no significant losses / N...
# 1                                          Charl to fix
# 2         Charl inspected site and will have to return
# 3                Reconnect - Connection re-established
# 4                 Connection back with network renaming
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#      Report Copy/Paste Table Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0                       Date     Urgency   Component    Engineer      Status
# 1        2019-09-16 00:00:00         Low   PV System    Natheera      Closed
# 2        2019-09-11 00:00:00         Low   PV System    Natheera      Closed
# 3        2019-10-18 00:00:00        High  Monitoring       David      Closed
# 4        2019-10-06 00:00:00         Low   PV System    Natheera      Closed
# ...                      ...         ...         ...         ...         ...
# 1267                     NaN           0           0           0         NaN
# 1268                     NaN           0           0           0         NaN
# 1269                     NaN           0           0           0         NaN
# 1270                     NaN           0           0           0         NaN
# 1271                     NaN           0           0           0         NaN
#
#                                             Unnamed: 21 Unnamed: 22
# 0                                               Details         NaN
# 1                               System online. System 1      Closed
# 2                               System online. System 2         NaN
# 3     System 2 offline due to communication fault. C...         NaN
# 4                                    PV modules cleaned         NaN
# ...                                                 ...         ...
# 1267                                                NaN         NaN
# 1268                                                NaN         NaN
# 1269                                                NaN         NaN
# 1270                                                NaN         NaN
# 1271                                                NaN         NaN
#
# [1272 rows x 23 columns]

# %%
df.shape
# Out:
# (1272, 23)

# %%
df.dtypes
# Out:
# No.                           int64
# Project                      object
# Date                         object
# Date Issue Closed            object
# Rate Urgency                 object
# Component                    object
# Installation / Component     object
# Task Carried Out By          object
# Details                      object
# Status                       object
# Internal details             object
# Unnamed: 11                 float64
# Unnamed: 12                  object
# Lists                        object
# % Loss Due To Error          object
# Action / Result              object
# Report Copy/Paste Table      object
# Unnamed: 17                  object
# Unnamed: 18                  object
# Unnamed: 19                  object
# Unnamed: 20                  object
# Unnamed: 21                  object
# Unnamed: 22                  object
# dtype: object

# %%
df.columns
# Out:
# Index(['No.', 'Project', 'Date', 'Date Issue Closed', 'Rate Urgency',
#        'Component', 'Installation / Component', 'Task Carried Out By',
#        'Details ', 'Status', 'Internal details', 'Unnamed: 11', 'Unnamed: 12',
#        'Lists', '% Loss Due To Error', 'Action / Result',
#        'Report Copy/Paste Table', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
df.fillna(df.mean())
# Out:
#       No.  Project                 Date    Date Issue Closed Rate Urgency  \
# 0       0        +                  NaN                  NaN          NaN
# 1       0  Aerosud  2019-09-16 00:00:00  2019-09-16 00:00:00          Low
# 2       0  Aerosud  2019-09-11 00:00:00  2019-09-11 00:00:00          Low
# 3       0  Aerosud  2019-10-18 00:00:00  2019-10-24 00:00:00         High
# 4       0  Aerosud  2019-10-06 00:00:00  2019-10-06 00:00:00          Low
# ...   ...      ...                  ...                  ...          ...
# 1267    7      NaN                  NaN                  NaN          NaN
# 1268    7      NaN                  NaN                  NaN          NaN
# 1269    7      NaN                  NaN                  NaN          NaN
# 1270    7      NaN                  NaN                  NaN          NaN
# 1271    7      NaN                  NaN                  NaN          NaN
#
#        Component Installation / Component Task Carried Out By  \
# 0            NaN                      NaN                 NaN
# 1      PV System             Installation            Natheera
# 2      PV System             Installation            Natheera
# 3     Monitoring             Installation               David
# 4      PV System             Installation            Natheera
# ...          ...                      ...                 ...
# 1267         NaN                      NaN                 NaN
# 1268         NaN                      NaN                 NaN
# 1269         NaN                      NaN                 NaN
# 1270         NaN                      NaN                 NaN
# 1271         NaN                      NaN                 NaN
#
#                                                Details   Status  ...  \
# 0                                                   NaN     NaN  ...
# 1                               System online. System 1  Closed  ...
# 2                               System online. System 2  Closed  ...
# 3     System 2 offline due to communication fault. C...  Closed  ...
# 4                                    PV modules cleaned  Closed  ...
# ...                                                 ...     ...  ...
# 1267                                                NaN     NaN  ...
# 1268                                                NaN     NaN  ...
# 1269                                                NaN     NaN  ...
# 1270                                                NaN     NaN  ...
# 1271                                                NaN     NaN  ...
#
#           Lists  % Loss Due To Error  \
# 0        Status                  NaN
# 1         Open                   NaN
# 2        Closed                  NaN
# 3           NaN                  NaN
# 4     Component                  NaN
# ...         ...                  ...
# 1267        NaN                  NaN
# 1268        NaN                  NaN
# 1269        NaN                  NaN
# 1270        NaN                  NaN
# 1271        NaN                  NaN
#
#                                         Action / Result  \
# 0     Analysis performed / no significant losses / N...
# 1                                          Charl to fix
# 2         Charl inspected site and will have to return
# 3                Reconnect - Connection re-established
# 4                 Connection back with network renaming
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#      Report Copy/Paste Table Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0                       Date     Urgency   Component    Engineer      Status
# 1        2019-09-16 00:00:00         Low   PV System    Natheera      Closed
# 2        2019-09-11 00:00:00         Low   PV System    Natheera      Closed
# 3        2019-10-18 00:00:00        High  Monitoring       David      Closed
# 4        2019-10-06 00:00:00         Low   PV System    Natheera      Closed
# ...                      ...         ...         ...         ...         ...
# 1267                     NaN           0           0           0         NaN
# 1268                     NaN           0           0           0         NaN
# 1269                     NaN           0           0           0         NaN
# 1270                     NaN           0           0           0         NaN
# 1271                     NaN           0           0           0         NaN
#
#                                             Unnamed: 21 Unnamed: 22
# 0                                               Details         NaN
# 1                               System online. System 1      Closed
# 2                               System online. System 2         NaN
# 3     System 2 offline due to communication fault. C...         NaN
# 4                                    PV modules cleaned         NaN
# ...                                                 ...         ...
# 1267                                                NaN         NaN
# 1268                                                NaN         NaN
# 1269                                                NaN         NaN
# 1270                                                NaN         NaN
# 1271                                                NaN         NaN
#
# [1272 rows x 23 columns]

# %%
Project = df["Project"]
array = Project.values

# %%
df1 = pd.DataFrame(array, columns=['Project'])
df1
# Out:
#       Project
# 0           +
# 1     Aerosud
# 2     Aerosud
# 3     Aerosud
# 4     Aerosud
# ...       ...
# 1267      NaN
# 1268      NaN
# 1269      NaN
# 1270      NaN
# 1271      NaN
#
# [1272 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1272 entries, 0 to 1271
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   No.                       1272 non-null   int64
#  1   Project                   1114 non-null   object
#  2   Date                      1112 non-null   object
#  3   Date Issue Closed         947 non-null    object
#  4   Rate Urgency              1113 non-null   object
#  5   Component                 1072 non-null   object
#  6   Installation / Component  1049 non-null   object
#  7   Task Carried Out By       1070 non-null   object
#  8   Details                   1113 non-null   object
#  9   Status                    1110 non-null   object
#  10  Internal details          65 non-null     object
#  11  Unnamed: 11               0 non-null      float64
#  12  Unnamed: 12               4 non-null      object
#  13  Lists                     17 non-null     object
#  14  % Loss Due To Error       6 non-null      object
#  15  Action / Result           249 non-null    object
#  16  Report Copy/Paste Table   1260 non-null   object
#  17  Unnamed: 17               1272 non-null   object
#  18  Unnamed: 18               1272 non-null   object
#  19  Unnamed: 19               1272 non-null   object
#  20  Unnamed: 20               1260 non-null   object
#  21  Unnamed: 21               1260 non-null   object
#  22  Unnamed: 22               1 non-null      object
# dtypes: float64(1), int64(1), object(21)
# memory usage: 228.7+ KB

# %%
    df.fillna(df.mode())
# Out:
#       No.  Project                 Date    Date Issue Closed Rate Urgency  \
# 0       0        +  2020-02-01 00:00:00  2020-02-29 00:00:00         High
# 1       0  Aerosud  2019-09-16 00:00:00  2019-09-16 00:00:00          Low
# 2       0  Aerosud  2019-09-11 00:00:00  2019-09-11 00:00:00          Low
# 3       0  Aerosud  2019-10-18 00:00:00  2019-10-24 00:00:00         High
# 4       0  Aerosud  2019-10-06 00:00:00  2019-10-06 00:00:00          Low
# ...   ...      ...                  ...                  ...          ...
# 1267    7      NaN                  NaT                  NaT          NaN
# 1268    7      NaN                  NaT                  NaT          NaN
# 1269    7      NaN                  NaT                  NaT          NaN
# 1270    7      NaN                  NaT                  NaT          NaN
# 1271    7      NaN                  NaT                  NaT          NaN
#
#        Component Installation / Component Task Carried Out By  \
# 0      PV System             Installation            Natheera
# 1      PV System             Installation            Natheera
# 2      PV System             Installation            Natheera
# 3     Monitoring             Installation               David
# 4      PV System             Installation            Natheera
# ...          ...                      ...                 ...
# 1267         NaN                      NaN                 NaN
# 1268         NaN                      NaN                 NaN
# 1269         NaN                      NaN                 NaN
# 1270         NaN                      NaN                 NaN
# 1271         NaN                      NaN                 NaN
#
#                                                Details   Status  ...  \
# 0                                         System online  Closed  ...
# 1                               System online. System 1  Closed  ...
# 2                               System online. System 2  Closed  ...
# 3     System 2 offline due to communication fault. C...  Closed  ...
# 4                                    PV modules cleaned  Closed  ...
# ...                                                 ...     ...  ...
# 1267                                                NaN     NaN  ...
# 1268                                                NaN     NaN  ...
# 1269                                                NaN     NaN  ...
# 1270                                                NaN     NaN  ...
# 1271                                                NaN     NaN  ...
#
#           Lists  % Loss Due To Error  \
# 0        Status               Closed
# 1         Open                   NaN
# 2        Closed                  NaN
# 3           NaN                  NaN
# 4     Component                  NaN
# ...         ...                  ...
# 1267        NaN                  NaN
# 1268        NaN                  NaN
# 1269        NaN                  NaN
# 1270        NaN                  NaN
# 1271        NaN                  NaN
#
#                                         Action / Result  \
# 0     Analysis performed / no significant losses / N...
# 1                                          Charl to fix
# 2         Charl inspected site and will have to return
# 3                Reconnect - Connection re-established
# 4                 Connection back with network renaming
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#      Report Copy/Paste Table Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0                       Date     Urgency   Component    Engineer      Status
# 1        2019-09-16 00:00:00         Low   PV System    Natheera      Closed
# 2        2019-09-11 00:00:00         Low   PV System    Natheera      Closed
# 3        2019-10-18 00:00:00        High  Monitoring       David      Closed
# 4        2019-10-06 00:00:00         Low   PV System    Natheera      Closed
# ...                      ...         ...         ...         ...         ...
# 1267                     NaN           0           0           0         NaN
# 1268                     NaN           0           0           0         NaN
# 1269                     NaN           0           0           0         NaN
# 1270                     NaN           0           0           0         NaN
# 1271                     NaN           0           0           0         NaN
#
#                                             Unnamed: 21 Unnamed: 22
# 0                                               Details      Closed
# 1                               System online. System 1      Closed
# 2                               System online. System 2         NaN
# 3     System 2 offline due to communication fault. C...         NaN
# 4                                    PV modules cleaned         NaN
# ...                                                 ...         ...
# 1267                                                NaN         NaN
# 1268                                                NaN         NaN
# 1269                                                NaN         NaN
# 1270                                                NaN         NaN
# 1271                                                NaN         NaN
#
# [1272 rows x 23 columns]

# %%
import seaborn as sns

# %%
sns.barplot('No.', 'Lists', data= df)
# Out:
# /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='No.', ylabel='Lists'>

# %%
sns.pairplot(df)

# %%
sns.boxenplot("No." , "Lists" , data = df)
# Out:
# /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='No.', ylabel='Lists'>

# %%
df1 = pd.read_excel('/Users/ahmadasdo/Library/Containers/com.microsoft.Excel/Data/Downloads/Book (2).xlsx')

# %%
df1.sample(20)
# Out:
#                     Site     Size  \
# 119  Tonk Meter Crossing   400.00
# 49      Groot Constantia    51.48
# 55        Historic Wines    84.00
# 11                   AVI      NaN
# 38        Dube Tradeport   312.00
# 96              Pakworks   573.00
# 66              La Motte   100.00
# 109         Sable Square   808.00
# 124      Umphakathi Mall   932.00
# 59     IPS - 10 Carlisle   100.00
# 54         Highland Mews  1069.00
# 113        Skye Footwear   150.00
# 29     Cresta Junction C    58.00
# 79              MegaPark  1199.97
# 73      Louwlardia Ext74   350.00
# 78       Manhattan Plaza   136.00
# 100  Plantation Shutters    92.40
# 0                      1     2.00
# 24       Cinnamon Square   243.00
# 115         Stanger Mall  1172.00
#
#                                               Location   Commissioning Date  \
# 119    Tonk Meter Crossing, Rhokana Street, &, Springs  2020-11-23 00:00:00
# 49                      9 Rustenburg Avenue, Cape Town  2018-11-14 00:00:00
# 55            Omuranba Rd, Montagur Gardens, Cape Town  2015-12-01 00:00:00
# 11                                                 NaN                  NaN
# 38                        29°36'22.71"S, 31°06'56.52"E  2018-05-11 00:00:00
# 96                        Longmarkt St, Heilbron, 9650  2020-10-01 00:00:00
# 66                    R45 Main Road, Franschhoek, 7690  2015-12-01 00:00:00
# 109  Cnr Bosmansdam & Ratanga Rd, Milnerton, Cape T...  2018-10-04 00:00:00
# 124  , Main Reef Road & R559, Middelvlei 255-Iq, Ra...                  NaN
# 59                       IPS Property - 10 Carlisle Rd                  NaN
# 54                         Del Judor, Emalahleni, 1044  2021-04-19 00:00:00
# 113                  6 Renaissance Drive, Johannesburg  2018-02-26 00:00:00
# 29                          13 Judges Avenue, Randburg  2016-11-01 00:00:00
# 79   Mega Park, Mill Rd, Bellville South, Cape Town...                  NaN
# 73                    Olievenhoutsbosch Ave, Centurion  2017-12-08 00:00:00
# 78                           96 Edward Road, Bellville  2020-11-01 00:00:00
# 100         8 Josias Blanckenberg Road, Atlantis, 7349  2018-06-07 00:00:00
# 0                                                    3                    4
# 24         Cnr Rusthof Rd & Gordon's Bay Drive, Strand  2019-04-08 00:00:00
# 115                      2 Elizabeth Street, Kwadukuza  2019-06-13 00:00:00
#
#                      Contact Person  \
# 119  Adam Markovitz, Lionel Kisten
# 49                       Jean Naude
# 55                            Andus
# 11                              NaN
# 38                      Anton Kotze
# 96                    Migal Jordaan
# 66                   Paul Neethling
# 109              Marius Heydenreich
# 124              Moegamad, Fransois
# 59                    Andy Shordits
# 54                              NaN
# 113                   Hassan Sattar
# 29                  Suraj Lallchand
# 79               Maxime Cornil-Dieu
# 73                     PC Potgieter
# 78                 Garrit Henkelman
# 100      Werner Jansen Van Rensburg
# 0                                 5
# 24                    Braam van Zyl
# 115                             LTM
#
#                                                  Email  \
# 119         Adam@markland.co.za; Lionel@markland.co.za
# 49                    Jean.Naude@grootconstantia.co.za
# 55                              ad@historicwines.co.za
# 11                                                 NaN
# 38                              anton@ltmenergy.co.za
# 96                               migal@solarafrica.com
# 66                             pjn@historicwines.co.za
# 109                              mariush@sablesq.co.za
# 124  moegamat@metbuilders.co.za; francoislouw@metbu...
# 59                                      andy@ips.co.za
# 54                                                 NaN
# 113                              hsattar@lagroup.co.za
# 29                               surajl@fedgroup.co.za
# 79   maxime.cornil-dieu@capvertenergie.com; Exploit...
# 73                      PotgieterPC@fortressfund.co.za
# 78                          operations@spearprop.co.za
# 100  accounts@plantation.co.za; werner@plantation.c...
# 0                                                    6
# 24                                  BVanZyl@7-11.co.za
# 115                            mukhuru@ltmenergy.co.za
#
#                    Contact No.  Consumption Monitoring Platform  \
# 119                  0732969204         Yes           SolarEdge
# 49                          NaN         Yes           SolarEdge
# 55                          NaN          No           Solar-log
# 11                          NaN          No           Solar-log
# 38   082 604 5244, 011 042 3027          No           Solar-log
# 96                 087 095 0553          No           SolarEdge
# 66                          NaN          No           Solar-log
# 109                082 574 8058          No           SolarEdge
# 124             +27 83 645 3870          No        Fusion Solar
# 59                          NaN         NaN                 NaN
# 54                          NaN         Yes          Solar Edge
# 113                021 683 1786         Yes           SolarEdge
# 29                          NaN         Yes           SolarEdge
# 79                          NaN         NaN              NetEco
# 73                 012 771 2803         Yes        Meteocontrol
# 78        0826815660/0212862700         Yes           SolarEdge
# 100                021 577 1705         Yes           SolarEdge
# 0                             7           8                   9
# 24                 021 535 1711         Yes           SolarEdge
# 115                   110423027          No           Solar-log
#
#                     Mounting Type   Maintenance Contract  Year  Year Month  \
# 119  Roof Mounted Solar PV System                    O&M  2020  Nov - 2020
# 49   Roof Mounted Solar PV System                   None  2018  Nov - 2018
# 55   Roof Mounted Solar PV System             Monitoring  2015  Dec - 2015
# 11   Roof Mounted Solar PV System                   None
# 38   Roof Mounted Solar PV System                   None  2018  May - 2018
# 96   Roof Mounted Solar PV System  Performance Guarantee  2020  Oct - 2020
# 66   Roof Mounted Solar PV System             Monitoring  2015  Dec - 2015
# 109  Roof Mounted Solar PV System  Performance Guarantee  2018  Oct - 2018
# 124  Roof Mounted Solar PV System         Defects Period
# 59                            NaN         Defects Period
# 54   Roof Mounted Solar PV System  Performance Guarantee  2021  Apr - 2021
# 113  Roof Mounted Solar PV System                   None  2018  Feb - 2018
# 29   Roof Mounted Solar PV System  Performance Guarantee  2016  Nov - 2016
# 79   Roof Mounted Solar PV System  Performance Guarantee
# 73   Roof Mounted Solar PV System             Monitoring  2017  Dec - 2017
# 78   Roof Mounted Solar PV System  Performance Guarantee  2020  Nov - 2020
# 100  Roof Mounted Solar PV System  Performance Guarantee  2018  Jun - 2018
# 0                              10                     11    12          13
# 24   Roof Mounted Solar PV System  Performance Guarantee  2019  Apr - 2019
# 115  Roof Mounted Solar PV System         Defects Period  2019  Jun - 2019
#
#     Fedgroup Fedgroup Contract  Contract number of years             Funder  \
# 119        N               NaN                       NaN             Client
# 49         N               NaN                       NaN             Client
# 55         N               NaN                       NaN             Client
# 11         N               NaN                       NaN             Client
# 38         N               NaN                       NaN             Client
# 96         N               NaN                       NaN       Solar Africa
# 66         N               NaN                       NaN             Client
# 109        N               NaN                       NaN             Client
# 124      NaN               NaN                       NaN                NaN
# 59       NaN               NaN                       NaN             Client
# 54         N               NaN                       NaN             Client
# 113        N               NaN                       NaN             Client
# 29         Y               RRI                       NaN             FII154
# 79         N               NaN                       NaN                CVE
# 73         N               NaN                       NaN             Client
# 78         Y               RRI                       NaN  Fedgroup Ventures
# 100        Y               LTO                       NaN  Fedgroup Ventures
# 0         14                15                      16.0                 17
# 24         Y               LTO                       NaN             FII154
# 115        N               NaN                       NaN                LTM
#
#     Monitor
# 119     Yes
# 49       No
# 55       No
# 11       No
# 38       No
# 96      Yes
# 66       No
# 109     Yes
# 124     NaN
# 59      Yes
# 54      Yes
# 113     Yes
# 29      Yes
# 79      Yes
# 73       No
# 78      Yes
# 100     Yes
# 0        18
# 24      Yes
# 115      No

# %%
df1.fillna(df.mode())
# Out:
#                            Site    Size  \
# 0                             1    2.00
# 1              5 Star Superspar  380.00
# 2                 7-11 Atlantis  157.00
# 3                  78 on Edward   64.34
# 4                       Aerosud  574.00
# ..                          ...     ...
# 130               Vrystaat Spar  178.20
# 131                         WAG  175.00
# 132           Whitehouse Centre   52.00
# 133      Wine of the Month Club   48.84
# 134  Worldwide Automotive Group  175.00
#
#                                          Location   Commissioning Date  \
# 0                                               3                    4
# 1    Nelson Mandela Drive, Vaalrivier St, Secunda  2020-08-31 00:00:00
# 2    1 Amstelveen Crescent, Avondale,Atlantis,Cpt  2020-07-25 00:00:00
# 3                       78 Edward Road, Cape Town  2020-01-28 00:00:00
# 4               520 Van Rybeveld Avenue, Pretoria  2019-10-08 00:00:00
# ..                                            ...                  ...
# 130               172 OR Tambo Road, Bloemfontein  2018-04-13 00:00:00
# 131                                           NaN                  NaN
# 132             56 Mahatma Ghandi Street, Stanger  2019-11-01 00:00:00
# 133                Capricorn Boulevard, Cape Town  2019-01-01 00:00:00
# 134            122 Olievenhoutbosch Rd, Centurion  2019-05-10 00:00:00
#
#                       Contact Person                        Email  \
# 0                                  5                            6
# 1                              Chris   chris@5starsuperspar.co.za
# 2                      Braam van Zyl           BVanZyl@7-11.co.za
# 3                   Garrit Henkelman   operations@spearprop.co.za
# 4                   Deon Labuschagne  d.labuschagne@aerosud.co.za
# ..                               ...                          ...
# 130  Serafim Pestana Das Ramos Ramos            serram@mweb.co.za
# 131                              NaN                          NaN
# 132                     Salim Tootla        salimtootla@gmail.com
# 133                     Gis Collard      gis@wineofthemonth.co.za
# 134                   Jannie Viljoen          jannie@inceku.co.za
#
#               Contact No.  Consumption Monitoring Platform  \
# 0                        7           8                   9
# 1             083 321 0444         Yes                Elum
# 2             021 535 1711         Yes           SolarEdge
# 3    0826815660/0212862700         Yes           SolarEdge
# 4             012 662 5055          No              NetEco
# ..                     ...         ...                 ...
# 130             0824639882         Yes           SolarEdge
# 131           076 934 2621          No           Solar-log
# 132             0836628118         Yes           SolarEdge
# 133           021 492 4100         Yes           SolarEdge
# 134           012 771 2803          No           Solar-log
#
#                     Mounting Type   Maintenance Contract  Year  Year Month  \
# 0                              10                     11    12          13
# 1    Roof Mounted Solar PV System         Defects Period  2020  Aug - 2020
# 2    Roof Mounted Solar PV System         Defects Period  2020  Jul - 2020
# 3    Roof Mounted Solar PV System  Performance Guarantee  2020  Jan - 2020
# 4         Carport Solar PV System  Performance Guarantee  2019  Oct - 2019
# ..                            ...                    ...   ...         ...
# 130  Roof Mounted Solar PV System                   None  2018  Apr - 2018
# 131  Roof Mounted Solar PV System                   None
# 132  Roof Mounted Solar PV System         Defects Period  2019  Nov - 2019
# 133  Roof Mounted Solar PV System  Performance Guarantee  2019  Jan - 2019
# 134  Roof Mounted Solar PV System         Defects Period  2019  May - 2019
#
#     Fedgroup Fedgroup Contract  Contract number of years             Funder  \
# 0         14                15                      16.0                 17
# 1          N               NaN                       NaN             Client
# 2          N               NaN                       NaN             Client
# 3          Y               LTO                       NaN  Fedgroup Ventures
# 4          Y               LTO                       NaN             FII154
# ..       ...               ...                       ...                ...
# 130        N               LTO                       NaN             Client
# 131        N               NaN                       NaN             Client
# 132        N               NaN                       NaN             Client
# 133        Y               LTO                       NaN  Fedgroup Ventures
# 134        N               NaN                       NaN             Client
#
#     Monitor
# 0        18
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
# ..      ...
# 130     Yes
# 131      No
# 132      No
# 133     Yes
# 134      No
#
# [135 rows x 18 columns]

# %%
sns.pairplot(df1)

# %%
sns.boxplot("Size", "Year", data = df1)
# Out:
# /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Size', ylabel='Year'>

# %%
sns.boxenplot("Size","Monitor", hue = "Consumption", data = df1)
# Out:
# /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Size', ylabel='Monitor'>

# %%
pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.14.0 in /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages (from category_encoders) (1.20.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages (from category_encoders) (0.24.1)
# Requirement already satisfied: pandas>=0.21.1 in /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages (from category_encoders) (1.2.4)
# Requirement already satisfied: scipy>=1.0.0 in /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages (from category_encoders) (1.6.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages (from category_encoders) (0.12.2)
# Requirement already satisfied: patsy>=0.5.1 in /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.21.1->category_encoders) (2021.1)
# Requirement already satisfied: six in /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->category_encoders) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->category_encoders) (2.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import category_encoders as ce

# %%
encoder= ce.OrdinalEncoder(cols=['Maintenance Contract'],return_df=True,
                           mapping=[{'col':'Maintenance Contract',
'mapping':{'None':0,'Defects Period':1,'Performance Guarantee':2, 'Monitoring':3, 'O&M':4, '11':5, 'Platform Monitoring':6}}])

# %%
df_train_transformed = encoder.fit_transform(df1)
# Out:
# /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
df_train_transformed.sample(15)
# Out:
#                     Site     Size  \
# 65                 K-Way    82.55
# 132    Whitehouse Centre    52.00
# 122       Tyre Recyclers   231.00
# 82                   MES   113.00
# 48     Graymaur Plastics   294.00
# 38        Dube Tradeport   312.00
# 9       Atlantic Abalone   261.00
# 105    Queenstown Nonesi  1292.00
# 32       De Grendel Roof    21.00
# 56            HomeChoice   662.00
# 128      VKB - Frankfort   800.00
# 76   Malvern Engineering   120.00
# 15            Botshabelo    30.00
# 2          7-11 Atlantis   157.00
# 44              Fairview   294.00
#
#                                               Location   Commissioning Date  \
# 65              Melviller Road, Ottery East, Cape Town  2017-08-15 00:00:00
# 132                  56 Mahatma Ghandi Street, Stanger  2019-11-01 00:00:00
# 122  Harry Alexander Cres, Atlantis Industrial, Das...  2018-08-15 00:00:00
# 82               1 Hiles Road, Korsten, Port Elizabeth  2017-12-25 00:00:00
# 48     93 Juta Rd, Schauderville, Port Elizabeth, 6001  2020-07-01 00:00:00
# 38                        29°36'22.71"S, 31°06'56.52"E  2018-05-11 00:00:00
# 9                           Gansbaai Harbour, Gansbaai  2015-02-07 00:00:00
# 105                 8698 Victoria Rd, Queenstown, 5320  2021-03-26 00:00:00
# 32               112 Plattekloof Road, Cape Town, 7500  2015-02-12 00:00:00
# 56      78 Main Road, Wynberg, Cape Town, Western Cape  2020-10-10 00:00:00
# 128                   15 Villiers Weg, Frankfort, 9830  2020-10-24 00:00:00
# 76                                                 NaN                  NaN
# 15                           Maud Avenue, Johannesburg  2018-07-13 00:00:00
# 2         1 Amstelveen Crescent, Avondale,Atlantis,Cpt  2020-07-25 00:00:00
# 44             Suid-Agter-Paarl Rd, Suider-Paarl, 7646  2019-02-21 00:00:00
#
#                 Contact Person  \
# 65              Bobby Fairlamb
# 132               Salim Tootla
# 122              Karlu van Eck
# 82             Suraj Lallchand
# 48              Robyn Overbury
# 38                 Anton Kotze
# 9                 Deon Killian
# 105                        NaN
# 32              Pierre Viljoen
# 56   Roger King, Johann Klindt
# 128           Ruhan Theunissen
# 76                         NaN
# 15             Suraj Lallchand
# 2                Braam van Zyl
# 44               Andor Hanekom
#
#                                                 Email  \
# 65                                   bobby@kway.co.za
# 132                             salimtootla@gmail.com
# 122                       sales@satyrerecyclers.co.za
# 82                              surajl@fedgroup.co.za
# 48                              robyno@fedgroup.co.za
# 38                             anton@ltmenergy.co.za
# 9                                doenk@premfish.co.za
# 105                                               NaN
# 32                             pierre@degrendel.co.za
# 56   rking@homechoice.co.za; jklindt@homechoice.co.za
# 128                        ruhan.theunissen@vkb.co.za
# 76                                                NaN
# 15                              surajl@fedgroup.co.za
# 2                                  BVanZyl@7-11.co.za
# 44                               andor@fairview.co.za
#
#                    Contact No.  Consumption Monitoring Platform  \
# 65                 021 704 9913         Yes           SolarEdge
# 132                  0836628118         Yes           SolarEdge
# 122                084 856 3128          No           SolarEdge
# 82                          NaN          No           SolarEdge
# 48                 011 305 2300          No           SolarEdge
# 38   082 604 5244, 011 042 3027          No           Solar-log
# 9                  028 384 1162          No           Solar-log
# 105                         NaN          No          Solar Edge
# 32                          NaN          No           Solar-log
# 56                 021 680 1409         Yes           SolarEdge
# 128                         NaN         Yes           Solar-log
# 76                          NaN         NaN                 NaN
# 15                          NaN         Yes           SolarEdge
# 2                  021 535 1711         Yes           SolarEdge
# 44                 021 863 3959          No        Fusion Solar
#
#                     Mounting Type  Maintenance Contract  Year  Year Month  \
# 65   Roof Mounted Solar PV System                   0.0  2017  Aug - 2017
# 132  Roof Mounted Solar PV System                   1.0  2019  Nov - 2019
# 122  Roof Mounted Solar PV System                   2.0  2018  Aug - 2018
# 82   Roof Mounted Solar PV System                   2.0  2017  Dec - 2017
# 48   Roof Mounted Solar PV System                   2.0  2020  Jul - 2020
# 38   Roof Mounted Solar PV System                   0.0  2018  May - 2018
# 9         Carport Solar PV System                   6.0  2015  Feb - 2015
# 105  Roof Mounted Solar PV System                   2.0  2021  Mar - 2021
# 32   Roof Mounted Solar PV System                   3.0  2015  Feb - 2015
# 56   Roof Mounted Solar PV System                   1.0  2020  Oct - 2020
# 128  Roof Mounted Solar PV System                   1.0  2020  Oct - 2020
# 76                            NaN                   2.0
# 15   Roof Mounted Solar PV System                   2.0  2018  Jul - 2018
# 2    Roof Mounted Solar PV System                   1.0  2020  Jul - 2020
# 44   Roof Mounted Solar PV System                   1.0  2019  Feb - 2019
#
#     Fedgroup Fedgroup Contract  Contract number of years             Funder  \
# 65         N               NaN                       NaN             Client
# 132        N               NaN                       NaN             Client
# 122        Y               LTO                       NaN             FII154
# 82         Y               RRI                       NaN  Fedgroup Ventures
# 48         Y               RRI                       NaN  Fedgroup Ventures
# 38         N               NaN                       NaN             Client
# 9          N               NaN                       NaN             Client
# 105        N               NaN                       NaN             Client
# 32         N               NaN                       NaN             Client
# 56         N               NaN                       NaN             Client
# 128        N               NaN                       NaN             Client
# 76       NaN               NaN                       NaN             Client
# 15         Y               RRI                       NaN  Fedgroup Ventures
# 2          N               NaN                       NaN             Client
# 44         N               NaN                       NaN             Client
#
#     Monitor
# 65       No
# 132      No
# 122     Yes
# 82      Yes
# 48      Yes
# 38       No
# 9        No
# 105     Yes
# 32      Yes
# 56      Yes
# 128     Yes
# 76      Yes
# 15      Yes
# 2       Yes
# 44      Yes

# %%
sns.catplot("Site" , "Maintenance Contract", data = df_train_transformed)
# Out:
# /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_train_transformed.fillna(df_train_transformed.mode())
# Out:
# /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages/pandas/core/algorithms.py:944: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'int'
#   warn(f"Unable to sort modes: {err}")
#                            Site    Size  \
# 0                             1    2.00
# 1              5 Star Superspar  380.00
# 2                 7-11 Atlantis  157.00
# 3                  78 on Edward   64.34
# 4                       Aerosud  574.00
# ..                          ...     ...
# 130               Vrystaat Spar  178.20
# 131                         WAG  175.00
# 132           Whitehouse Centre   52.00
# 133      Wine of the Month Club   48.84
# 134  Worldwide Automotive Group  175.00
#
#                                          Location   Commissioning Date  \
# 0                                               3                    4
# 1    Nelson Mandela Drive, Vaalrivier St, Secunda  2020-08-31 00:00:00
# 2    1 Amstelveen Crescent, Avondale,Atlantis,Cpt  2020-07-25 00:00:00
# 3                       78 Edward Road, Cape Town  2020-01-28 00:00:00
# 4               520 Van Rybeveld Avenue, Pretoria  2019-10-08 00:00:00
# ..                                            ...                  ...
# 130               172 OR Tambo Road, Bloemfontein  2018-04-13 00:00:00
# 131                                           NaN                  NaT
# 132             56 Mahatma Ghandi Street, Stanger  2019-11-01 00:00:00
# 133                Capricorn Boulevard, Cape Town  2019-01-01 00:00:00
# 134            122 Olievenhoutbosch Rd, Centurion  2019-05-10 00:00:00
#
#                       Contact Person                        Email  \
# 0                                  5                            6
# 1                              Chris   chris@5starsuperspar.co.za
# 2                      Braam van Zyl           BVanZyl@7-11.co.za
# 3                   Garrit Henkelman   operations@spearprop.co.za
# 4                   Deon Labuschagne  d.labuschagne@aerosud.co.za
# ..                               ...                          ...
# 130  Serafim Pestana Das Ramos Ramos            serram@mweb.co.za
# 131                              NaN                          NaN
# 132                     Salim Tootla        salimtootla@gmail.com
# 133                     Gis Collard      gis@wineofthemonth.co.za
# 134                   Jannie Viljoen          jannie@inceku.co.za
#
#               Contact No.  Consumption Monitoring Platform  \
# 0                        7           8                   9
# 1             083 321 0444         Yes                Elum
# 2             021 535 1711         Yes           SolarEdge
# 3    0826815660/0212862700         Yes           SolarEdge
# 4             012 662 5055          No              NetEco
# ..                     ...         ...                 ...
# 130             0824639882         Yes           SolarEdge
# 131           076 934 2621          No           Solar-log
# 132             0836628118         Yes           SolarEdge
# 133           021 492 4100         Yes           SolarEdge
# 134           012 771 2803          No           Solar-log
#
#                     Mounting Type  Maintenance Contract  Year  Year Month  \
# 0                              10                  -1.0    12          13
# 1    Roof Mounted Solar PV System                   1.0  2020  Aug - 2020
# 2    Roof Mounted Solar PV System                   1.0  2020  Jul - 2020
# 3    Roof Mounted Solar PV System                   2.0  2020  Jan - 2020
# 4         Carport Solar PV System                   2.0  2019  Oct - 2019
# ..                            ...                   ...   ...         ...
# 130  Roof Mounted Solar PV System                   0.0  2018  Apr - 2018
# 131  Roof Mounted Solar PV System                   0.0
# 132  Roof Mounted Solar PV System                   1.0  2019  Nov - 2019
# 133  Roof Mounted Solar PV System                   2.0  2019  Jan - 2019
# 134  Roof Mounted Solar PV System                   1.0  2019  May - 2019
#
#     Fedgroup Fedgroup Contract  Contract number of years             Funder  \
# 0         14                15                      16.0                 17
# 1          N               NaN                       NaN             Client
# 2          N               NaN                       NaN             Client
# 3          Y               LTO                       NaN  Fedgroup Ventures
# 4          Y               LTO                       NaN             FII154
# ..       ...               ...                       ...                ...
# 130        N               LTO                       NaN             Client
# 131        N               NaN                       NaN             Client
# 132        N               NaN                       NaN             Client
# 133        Y               LTO                       NaN  Fedgroup Ventures
# 134        N               NaN                       NaN             Client
#
#     Monitor
# 0        18
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
# ..      ...
# 130     Yes
# 131      No
# 132      No
# 133     Yes
# 134      No
#
# [135 rows x 18 columns]

# %%
encoder= ce.OrdinalEncoder(cols=['Consumption'],return_df=True,
                           mapping=[{'col':'Consumption',
'mapping':{'No':0,'Yes':1}}])

# %%
df_train_transformed = encoder.fit_transform(df1)
# Out:
# /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
df_train_transformed
# Out:
#                            Site    Size  \
# 0                             1    2.00
# 1              5 Star Superspar  380.00
# 2                 7-11 Atlantis  157.00
# 3                  78 on Edward   64.34
# 4                       Aerosud  574.00
# ..                          ...     ...
# 130               Vrystaat Spar  178.20
# 131                         WAG  175.00
# 132           Whitehouse Centre   52.00
# 133      Wine of the Month Club   48.84
# 134  Worldwide Automotive Group  175.00
#
#                                          Location   Commissioning Date  \
# 0                                               3                    4
# 1    Nelson Mandela Drive, Vaalrivier St, Secunda  2020-08-31 00:00:00
# 2    1 Amstelveen Crescent, Avondale,Atlantis,Cpt  2020-07-25 00:00:00
# 3                       78 Edward Road, Cape Town  2020-01-28 00:00:00
# 4               520 Van Rybeveld Avenue, Pretoria  2019-10-08 00:00:00
# ..                                            ...                  ...
# 130               172 OR Tambo Road, Bloemfontein  2018-04-13 00:00:00
# 131                                           NaN                  NaN
# 132             56 Mahatma Ghandi Street, Stanger  2019-11-01 00:00:00
# 133                Capricorn Boulevard, Cape Town  2019-01-01 00:00:00
# 134            122 Olievenhoutbosch Rd, Centurion  2019-05-10 00:00:00
#
#                       Contact Person                        Email  \
# 0                                  5                            6
# 1                              Chris   chris@5starsuperspar.co.za
# 2                      Braam van Zyl           BVanZyl@7-11.co.za
# 3                   Garrit Henkelman   operations@spearprop.co.za
# 4                   Deon Labuschagne  d.labuschagne@aerosud.co.za
# ..                               ...                          ...
# 130  Serafim Pestana Das Ramos Ramos            serram@mweb.co.za
# 131                              NaN                          NaN
# 132                     Salim Tootla        salimtootla@gmail.com
# 133                     Gis Collard      gis@wineofthemonth.co.za
# 134                   Jannie Viljoen          jannie@inceku.co.za
#
#               Contact No.   Consumption Monitoring Platform  \
# 0                        7         -1.0                   9
# 1             083 321 0444          1.0                Elum
# 2             021 535 1711          1.0           SolarEdge
# 3    0826815660/0212862700          1.0           SolarEdge
# 4             012 662 5055          0.0              NetEco
# ..                     ...          ...                 ...
# 130             0824639882          1.0           SolarEdge
# 131           076 934 2621          0.0           Solar-log
# 132             0836628118          1.0           SolarEdge
# 133           021 492 4100          1.0           SolarEdge
# 134           012 771 2803          0.0           Solar-log
#
#                     Mounting Type   Maintenance Contract  Year  Year Month  \
# 0                              10                     11    12          13
# 1    Roof Mounted Solar PV System         Defects Period  2020  Aug - 2020
# 2    Roof Mounted Solar PV System         Defects Period  2020  Jul - 2020
# 3    Roof Mounted Solar PV System  Performance Guarantee  2020  Jan - 2020
# 4         Carport Solar PV System  Performance Guarantee  2019  Oct - 2019
# ..                            ...                    ...   ...         ...
# 130  Roof Mounted Solar PV System                   None  2018  Apr - 2018
# 131  Roof Mounted Solar PV System                   None
# 132  Roof Mounted Solar PV System         Defects Period  2019  Nov - 2019
# 133  Roof Mounted Solar PV System  Performance Guarantee  2019  Jan - 2019
# 134  Roof Mounted Solar PV System         Defects Period  2019  May - 2019
#
#     Fedgroup Fedgroup Contract  Contract number of years             Funder  \
# 0         14                15                      16.0                 17
# 1          N               NaN                       NaN             Client
# 2          N               NaN                       NaN             Client
# 3          Y               LTO                       NaN  Fedgroup Ventures
# 4          Y               LTO                       NaN             FII154
# ..       ...               ...                       ...                ...
# 130        N               LTO                       NaN             Client
# 131        N               NaN                       NaN             Client
# 132        N               NaN                       NaN             Client
# 133        Y               LTO                       NaN  Fedgroup Ventures
# 134        N               NaN                       NaN             Client
#
#     Monitor
# 0        18
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
# ..      ...
# 130     Yes
# 131      No
# 132      No
# 133     Yes
# 134      No
#
# [135 rows x 18 columns]

# %%
sns.barplot("Site", "Consumption", data = df_train_transformed, hue ='Maintenance Contract' )
# Out:
# /Users/ahmadasdo/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Site', ylabel='Consumption'>
